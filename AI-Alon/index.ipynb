# %%
import requests

def generate_blog(api_key, prompt):
    try:
        # Endpoint for chat completions
        url = "https://api.openai.com/v1/chat/completions"

        # Headers and data for the API request
        headers = {
            "Authorization": f"Bearer {api_key}",
            "Content-Type": "application/json",
        }
        data = {
            "model": "gpt-3.5-turbo",
            "messages": [
                {"role": "system", "content": "Create a blog post."},
                {"role": "user", "content": prompt}
            ]
        }

        # Make the API request
        response = requests.post(url, headers=headers, json=data)
        response_data = response.json()

        # Extract the blog content from the response
        blog_content = response_data['choices'][0]['message']['content'].strip()

        return blog_content

    except Exception as e:
        return f"Error creating blog: {str(e)}"

def main():
    api_key = "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"
    prompt = input("Please enter the prompt for the blog: ")

    blog_content = generate_blog(api_key, prompt)
    print("\nGenerated Blog Content:\n")
    print(blog_content)

if __name__ == "__main__":
    main()
# Out:
# Generated Blog Content:
#
# קידום אתרים - הידיעה לא חדשה ולא נרדפת ובזמן האחרון עולה השאלה, מתי כדאי להתחיל לקדם אתר אינטרנט. זה יכול להיות שירות, עסק, חנות מקוונת, או אפילו בלוג.
#
# מי צריך קידום אתרים?
# תשובת פשוטה - כל מי שמעוניין שהאתר שלו יופיע בתוצאות הגוגל ושהאנשים יגיעו אליו בדרך טבעית. קידום אתרים מבצע עבודה אפקטיבית באמצעות שימוש במילות מפתח, עיצוב ממוקד ופרסום ברשתות חברתיות ומנועי חיפוש.
#
# לכן, כל בעל אתר שרוצה לראות תוצאות מורגשות ימצא שירותי קידום אתרים כמצרך בסיסי בייצוב האתר שלו במרחב הדיגיטלי.
#
# מתי כדאי להתחיל?
# התשובה היא במהלך בניית האתר. בהתחלה המטרה העיקרית היא להביא לאתר תמונות מוכנות במנועי חיפוש, יכולת החשיפה תלויה בהמון העבודה במהלך הבנייה של האתר. כדי להעבירת האתר לשלב הבא מומלץ להקדים את האתר בסמנים ובמילות מפתח עיקריות אשר הן דומות תחום כולל את שאר אפשרויות החיפוש שמבוצעות בגוגל.

# %%
import requests
import csv

def generate_blog(api_key, prompt):
    try:
        url = "https://api.openai.com/v1/chat/completions"
        headers = {
            "Authorization": f"Bearer {api_key}",
            "Content-Type": "application/json",
        }
        data = {
            "model": "gpt-3.5-turbo",
            "messages": [{"role": "system", "content": "Create a blog post."},
                         {"role": "user", "content": prompt}]
        }

        response = requests.post(url, headers=headers, json=data)
        response_data = response.json()

        if 'choices' in response_data and response_data['choices']:
            blog_content = response_data['choices'][0]['message']['content'].strip()
            return blog_content
        else:
            return "Error: No content generated by the API."

    except Exception as e:
        return f"Error creating blog: {str(e)}"

def save_to_text(html_content, file_name):
    with open(file_name, mode='w', encoding='utf-8') as file:
        file.write(html_content)


def main():
    api_key = "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"
    prompt = input("Please enter the prompt for the blog: ")

    blog_content = generate_blog(api_key, prompt)
    html_content = f"<html><body>{blog_content}</body></html>"

    save_to_text(html_content, "C:\\Store Data Set\\blog_post.txt")
    print("\nBlog content generated and saved to CSV.\n")

if __name__ == "__main__":
    main()
# Out:
# Blog content generated and saved to CSV.

# %%
import json
import requests

def generate_blog(api_key, prompt):
    try:
        url = "https://api.openai.com/v1/chat/completions"
        headers = {
            "Authorization": f"Bearer {api_key}",
            "Content-Type": "application/json",
        }
        data = {
            "model": "gpt-3.5-turbo",
            "messages": [{"role": "system", "content": "Create a blog post."},
                         {"role": "user", "content": prompt}]
        }

        response = requests.post(url, headers=headers, json=data)
        response_data = response.json()

        if 'choices' in response_data and response_data['choices']:
            blog_content = response_data['choices'][0]['message']['content'].strip()
            return blog_content
        else:
            return "Error: No content generated by the API."

    except Exception as e:
        return f"Error creating blog: {str(e)}"

def save_to_text(blog_content, file_name):
    # Prepare the HTML content
    html_content = f"<div><p>{blog_content}</p></div>"
    
    # Convert the HTML content to JSON format
    json_data = json.dumps({"content": html_content}, ensure_ascii=False)

    # Append the JSON data to the text file
    with open(file_name, mode='a', encoding='utf-8') as file:
        file.write(json_data + '\n')


def main():
    api_key = "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"
    prompt = input("Please enter the prompt for the blog: ")

    blog_content = generate_blog(api_key, prompt)

    save_to_text(blog_content, "C:\\Store Data Set\\blog_post.txt")
    print("\nBlog content generated and saved to text file.\n")

if __name__ == "__main__":
    main()
# Out:
# Blog content generated and saved to text file.

# %% [markdown]
# JSON

# %%
import json
import os

def generate_blog(api_key, prompt):
    # Placeholder for the AI-generated blog content
    # In a real implementation, call your API using the provided prompt and API key
    blog_content = f"<p>This is an AI-generated blog content based on prompt: '{prompt}'.</p>"
    return blog_content

def save_to_json(blog_content, file_path):
    # Prepare the JSON data with the blog content
    new_entry = {"content": blog_content}

    # Ensure the directory exists before saving
    os.makedirs(os.path.dirname(file_path), exist_ok=True)

    # Write the JSON data to the specified file path
    with open(file_path, mode='w', encoding='utf-8') as file:
        json.dump(new_entry, file, ensure_ascii=False)

def save_to_html(html_content, file_path):
    # Ensure the directory exists before saving
    os.makedirs(os.path.dirname(file_path), exist_ok=True)

    # Write the HTML content to the specified file path
    with open(file_path, mode='w', encoding='utf-8') as file:
        file.write(html_content)

def main():
    api_key = "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"
    prompt = input("Please enter the prompt for the blog: ")

    # Generate blog content
    blog_content = generate_blog(api_key, prompt)

    # Specify the file paths for the new blog JSON and HTML
    json_folder_path = r"C:\Users\alont\OneDrive\OneDrive 1\Documents\Store\dist\newblog"
    html_file_path = os.path.join(json_folder_path, "blog.html")
    json_file_path = os.path.join(json_folder_path, "blog.json")

    # Save blog content to JSON
    save_to_json(blog_content, json_file_path)
    print("\nBlog content generated and saved to JSON file.")

    # Prepare the HTML content with the blog content
    html_content = f"""
<!DOCTYPE html>
<html lang="he" dir="rtl">
<head>
    <meta charset="utf-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" />
    <meta name="description" content="" />
    <meta name="author" content="" />
    <title>Modern Business - Start Bootstrap Template</title>
    <!-- Favicon-->
    <link rel="icon" type="image/x-icon" href="assets/favicon.ico" />
    <!-- Bootstrap icons-->
    <link href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.5.0/font/bootstrap-icons.css" rel="stylesheet" />
    <!-- Core theme CSS (includes Bootstrap)-->
    <link href="css/styles.css" rel="stylesheet" />
</head>
<body class="d-flex flex-column">
    <main class="flex-shrink-0">
        <!-- Navigation-->
        <nav class="navbar navbar-expand-lg navbar-dark bg-dark">
            <div class="container px-5">
                <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation"><span class="navbar-toggler-icon"></span></button>
                <div class="collapse navbar-collapse" id="navbarSupportedContent">
                    <ul class="navbar-nav ms-auto mb-2 mb-lg-0">
                        <li class="nav-item"><a class="nav-link" href="index.html">דף הבית</a></li>
                        <li class="nav-item"><a class="nav-link" href="about.html">עלינו</a></li>
                        <li class="nav-item"><a class="nav-link" href="contact.html">צור קשר</a></li>
                        <li class="nav-item"><a class="nav-link" href="pricing.html">מחירים</a></li>
                        <li class="nav-item"><a class="nav-link" href="faq.html">מידע נוסף</a></li>
                        <li class="nav-item dropdown">
                            <a class="nav-link dropdown-toggle" id="navbarDropdownBlog" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">בלוג</a>
                            <ul class="dropdown-menu dropdown-menu-end" aria-labelledby="navbarDropdownBlog">
                                <li><a class="dropdown-item" href="blog-home.html">בלוג - דף הבית</a></li>
                                <li><a class="dropdown-item" href="blog-post.html">פוסטים</a></li>
                            </ul>
                        </li>
                        <li class="nav-item dropdown">
                            <a class="nav-link dropdown-toggle" id="navbarDropdownPortfolio" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">תיק עבודות</a>
                            <ul class="dropdown-menu dropdown-menu-end" aria-labelledby="navbarDropdownPortfolio">
                                <li><a class="dropdown-item" href="portfolio-overview.html">צפה בתוצרים שלנו</a></li>
                                <li><a class="dropdown-item" href="portfolio-item.html">להקת אהלן </a></li>
                            </ul>
                        </li>
                    </ul>
                </div>
            </div>
            <a class="navbar-brand" href="index.html"><img src="./assets/LOGO33 (1).png" Id="Logo" alt=""></a>
        </nav>
        <!-- Page Content-->
        <section class="py-5">
            <div class="container px-5 my-5">
                <div class="row gx-5">
                    <div class="col-lg-3">
                        <div class="d-flex align-items-center mt-lg-5 mb-4">
                            <img class="img-fluid rounded-circle" src="https://dummyimage.com/50x50/ced4da/6c757d.jpg" alt="..." />
                            <div class="ms-3">
                                <div class="fw-bold">Valerie Luna</div>
                                <div class="text-muted">News, Business</div>
                            </div>
                        </div>
                    </div>
                    <div class="col-lg-9">
                        <!-- Post content-->
                        <article>
                            <!-- Post header-->
                            """

    # Save blog content to HTML
    save_to_html(html_content, html_file_path)
    print("\nHTML file created with blog content.")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 118
#     115     print("\nHTML file created with blog content.")
#     117 if __name__ == "__main__":
# --> 118     main()
#
# Cell In[27], line 42, in main()
#      39 json_file_path = os.path.join(json_folder_path, "blog.json")
#      41 # Save blog content to JSON
# ---> 42 save_to_json(blog_content, json_file_path)
#      43 print("\nBlog content generated and saved to JSON file.")
#      45 # Prepare the HTML content with the blog content
#
# Cell In[27], line 15, in save_to_json(blog_content, file_path)
#      12 new_entry = {"content": blog_content}
#      14 # Ensure the directory exists before saving
# ---> 15 os.makedirs(os.path.dirname(file_path), exist_ok=True)
#      17 # Write the JSON data to the specified file path
#      18 with open(file_path, mode='w', encoding='utf-8') as file:
#
# ...

# %%
import json
import requests
import os

def generate_blog(api_key, prompt):
    try:
        url = "https://api.openai.com/v1/chat/completions"
        headers = {
            "Authorization": f"Bearer {api_key}",
            "Content-Type": "application/json",
        }
        data = {
            "model": "gpt-3.5-turbo",
            "messages": [{"role": "system", "content": "Create a blog post."},
                         {"role": "user", "content": prompt}]
        }

        response = requests.post(url, headers=headers, json=data)
        response_data = response.json()

        if 'choices' in response_data and response_data['choices']:
            blog_content = response_data['choices'][0]['message']['content'].strip()
            return blog_content
        else:
            return "Error: No content generated by the API."

    except Exception as e:
        return f"Error creating blog: {str(e)}"

def save_to_html(html_content, file_path):
    # Ensure the directory exists before saving
    os.makedirs(os.path.dirname(file_path), exist_ok=True)

    # Write the HTML content to the specified file path
    with open(file_path, mode='w', encoding='utf-8') as file:
        file.write(html_content)

def save_to_json(blog_content, file_path):
    # Prepare the JSON data with the blog content
    new_entry = {"content": blog_content}

    # Ensure the directory exists before saving
    os.makedirs(os.path.dirname(file_path), exist_ok=True)

    # Write the JSON data to the specified file path
    with open(file_path, mode='w', encoding='utf-8') as file:
        json.dump(new_entry, file, ensure_ascii=False)

def main():
    api_key = "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"
    prompt = input("Please enter the prompt for the blog: ")

    # Generate blog content
    blog_content = generate_blog(api_key, prompt)

    # Specify the file paths for the new blog HTML and JSON
    html_file_path = "C:\\Projects\\Store\\dist\\blogz.html"
    json_file_path = "C:\\Store Data Set\\blog.json"

    # Prepare the HTML content with the blog content
    html_content = f"""
    <!DOCTYPE html>
    <html lang="he" dir="rtl">
    <head>
        <meta charset="utf-8" />
        <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" />
        <meta name="description" content="" />
        <meta name="author" content="" />
        <title>Modern Business - Start Bootstrap Template</title>
        <!-- Favicon-->
        <link rel="icon" type="image/x-icon" href="assets/favicon.ico" />
        <!-- Bootstrap icons-->
        <link href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.5.0/font/bootstrap-icons.css" rel="stylesheet" />
        <!-- Core theme CSS (includes Bootstrap)-->
        <link href="css/styles.css" rel="stylesheet" />
    </head>
    <body class="d-flex flex-column">
        <main class="flex-shrink-0">
            <!-- Navigation-->
            <nav class="navbar navbar-expand-lg navbar-dark bg-dark">
                <div class="container px-5">
                    <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation"><span class="navbar-toggler-icon"></span></button>
                    <div class="collapse navbar-collapse" id="navbarSupportedContent">
                        <ul class="navbar-nav ms-auto mb-2 mb-lg-0">
                            <li class="nav-item"><a class="nav-link" href="index.html">דף הבית</a></li>
                            <li class="nav-item"><a class="nav-link" href="about.html">עלינו</a></li>
                            <li class="nav-item"><a class="nav-link" href="contact.html">צור קשר</a></li>
                            <li class="nav-item"><a class="nav-link" href="pricing.html">מחירים</a></li>
                            <li class="nav-item"><a class="nav-link" href="faq.html">מידע נוסף</a></li>
                            <li class="nav-item dropdown">
                                <a class="nav-link dropdown-toggle" id="navbarDropdownBlog" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">בלוג</a>
                                <ul class="dropdown-menu dropdown-menu-end" aria-labelledby="navbarDropdownBlog">
                                    <li><a class="dropdown-item" href="blog-home.html">בלוג - דף הבית</a></li>
                                    <li><a class="dropdown-item" href="blog-post.html">פוסטים</a></li>
                                </ul>
                            </li>
                            <li class="nav-item dropdown">
                                <a class="nav-link dropdown-toggle" id="navbarDropdownPortfolio" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">תיק עבודות</a>
                                <ul class="dropdown-menu dropdown-menu-end" aria-labelledby="navbarDropdownPortfolio">
                                    <li><a class="dropdown-item" href="portfolio-overview.html">צפה בתוצרים שלנו</a></li>
                                    <li><a class="dropdown-item" href="portfolio-item.html">להקת אהלן </a></li>
                                </ul>
                            </li>
                        </ul>
                    </div>
                </div>
                <a class="navbar-brand" href="index.html"><img src="./assets/LOGO33 (1).png" Id="Logo" alt=""></a>
            </nav>
            <!-- Page Content-->
            <section class="py-5">
                <div class="container px-5 my-5">
                    <div class="row gx-5">
                        <div class="col-lg-3">
                            <div class="d-flex align-items-center mt-lg-5 mb-4">
                                <img class="img-fluid rounded-circle" src="https://dummyimage.com/50x50/ced4da/6c757d.jpg" alt="..." />
                                <div class="ms-3">
                                    <div class="fw-bold">Valerie Luna</div>
                                    <div class="text-muted">News, Business</div>
                                </div>
                            </div>
                        </div>
                        <div class="col-lg-9">
                            <!-- Post content-->
                            <article>
                                <!-- Post header-->
                                <header class="mb-4">
                                    <!-- Post title-->
                                    <h1 class="fw-bolder mb-1">Welcome to Blog Post!</h1>
                                    <!-- Post meta content-->
                                    <div class="text-muted fst-italic mb-2">January 1, 2023</div>
                                    <!-- Post categories-->
                                    <a class="badge bg-secondary text-decoration-none link-light" href="#!">Web Design</a>
                                    <a class="badge bg-secondary text-decoration-none link-light" href="#!">Freebies</a>
                                </header>
                                <!-- Preview image figure-->
                                <figure class="mb-4"><img class="img-fluid rounded" src="https://dummyimage.com/900x400/ced4da/6c757d.jpg" alt="..." /></figure>
                                <!-- Post content-->
                                <section class="mb-5">
                                    {blog_content}
                                </section>
                            </article>
                        </div>
                    </div>
                </div>
            </section>
        </main>
        <!-- Footer-->
        <footer class="bg-dark py-4 mt-auto">
            <div class="container px-5">
                <div class="row align-items-center justify-content-between flex-column flex-sm-row">
                    <div class="col-auto"><div class="small m-0 text-white">Copyright &copy; Your Website 2023</div></div>
                    <div class="col-auto">
                        <a class="link-light small" href="#!">Privacy</a>
                        <span class="text-white mx-1">&middot;</span>
                        <a class="link-light small" href="#!">Terms</a>
                        <span class="text-white mx-1">&middot;</span>
                        <a class="link-light small" href="#!">Contact</a>
                    </div>
                </div>
            </div>
        </footer>
        <!-- Bootstrap core JS-->
        <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
        <!-- Core theme JS-->
        <script src="js/scripts.js"></script>
    </body>
    </html>
    """

    # Save the HTML content to a file
    save_to_html(html_content, html_file_path)
    print("\nHTML file created with blog content.")

    # Save the blog content to a JSON file
    save_to_json(blog_content, json_file_path)
    print("\nBlog content saved to JSON file.")

if __name__ == "__main__":
    main()
# Out:
# HTML file created with blog content.
#
# Blog content saved to JSON file.

# %%
import json
import requests
import os

def generate_blog(api_key, prompt):
    url = "https://api.openai.com/v1/chat/completions"
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json",
    }
    data = {
        "model": "gpt-3.5-turbo",
        "messages": [
            {"role": "system", "content": "Create a blog post."},
            {"role": "user", "content": prompt}
        ]
    }

    response = requests.post(url, headers=headers, json=data)
    response_data = response.json()

    if 'choices' in response_data and response_data['choices']:
        blog_content = response_data['choices'][0]['message']['content'].strip()
        return blog_content
    else:
        return "Error: No content generated by the API."

def save_to_html(html_content, file_path):
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    with open(file_path, mode='w', encoding='utf-8') as file:
        file.write(html_content)

def save_to_json(html_content, blog_number, file_path):
    new_entry = {
        "html_content": html_content,
        "blog_number": blog_number
    }

    if os.path.exists(file_path):
        with open(file_path, mode='r', encoding='utf-8') as file:
            try:
                existing_data = json.load(file)
            except json.JSONDecodeError:
                existing_data = []
    else:
        existing_data = []

    existing_data.append(new_entry)

    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    with open(file_path, mode='w', encoding='utf-8') as file:
        json.dump(existing_data, file, ensure_ascii=False)

def main():
    api_key = "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"  # Use your actual API key
    prompt = input("Please enter the prompt for the blog: ")
    blog_content = generate_blog(api_key, prompt)

    json_file_path = "C:\\Store Data Set\\blog_post.json"  # Corrected path to the json file
    folder_path = "C:\\Projects\\Store\\dist\\newblog"
    os.makedirs(folder_path, exist_ok=True)

    blog_number = len([f for f in os.listdir(folder_path) if f.endswith('.html')]) + 1
    html_file_name = f"blog_{blog_number}.html"
    html_file_path = os.path.join(folder_path, html_file_name)
    # Prepare the HTML content with the blog content
    html_content = f"""
    <!DOCTYPE html>
    <html lang="he" dir="rtl">
    <head>
        <meta charset="utf-8" />
        <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" />
        <meta name="description" content="" />
        <meta name="author" content="" />
        <title>Modern Business - Start Bootstrap Template</title>
        <!-- Favicon-->
        <link rel="icon" type="image/x-icon" href="assets/favicon.ico" />
        <!-- Bootstrap icons-->
        <link href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.5.0/font/bootstrap-icons.css" rel="stylesheet" />
        <!-- Core theme CSS (includes Bootstrap)-->
        <link href="css/styles.css" rel="stylesheet" />
    </head>
    <body class="d-flex flex-column">
        <main class="flex-shrink-0">
            <!-- Navigation-->
            <nav class="navbar navbar-expand-lg navbar-dark bg-dark">
                <div class="container px-5">
                    <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation"><span class="navbar-toggler-icon"></span></button>
                    <div class="collapse navbar-collapse" id="navbarSupportedContent">
                        <ul class="navbar-nav ms-auto mb-2 mb-lg-0">
                            <li class="nav-item"><a class="nav-link" href="index.html">דף הבית</a></li>
                            <li class="nav-item"><a class="nav-link" href="about.html">עלינו</a></li>
                            <li class="nav-item"><a class="nav-link" href="contact.html">צור קשר</a></li>
                            <li class="nav-item"><a class="nav-link" href="pricing.html">מחירים</a></li>
                            <li class="nav-item"><a class="nav-link" href="faq.html">מידע נוסף</a></li>
                            <li class="nav-item dropdown">
                                <a class="nav-link dropdown-toggle" id="navbarDropdownBlog" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">בלוג</a>
                                <ul class="dropdown-menu dropdown-menu-end" aria-labelledby="navbarDropdownBlog">
                                    <li><a class="dropdown-item" href="blog-home.html">בלוג - דף הבית</a></li>
                                    <li><a class="dropdown-item" href="blog-post.html">פוסטים</a></li>
                                </ul>
                            </li>
                            <li class="nav-item dropdown">
                                <a class="nav-link dropdown-toggle" id="navbarDropdownPortfolio" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">תיק עבודות</a>
                                <ul class="dropdown-menu dropdown-menu-end" aria-labelledby="navbarDropdownPortfolio">
                                    <li><a class="dropdown-item" href="portfolio-overview.html">צפה בתוצרים שלנו</a></li>
                                    <li><a class="dropdown-item" href="portfolio-item.html">להקת אהלן </a></li>
                                </ul>
                            </li>
                        </ul>
                    </div>
                </div>
                <a class="navbar-brand" href="index.html"><img src="./assets/LOGO33 (1).png" Id="Logo" alt=""></a>
            </nav>
            <!-- Page Content-->
            <section class="py-5">
                <div class="container px-5 my-5">
                    <div class="row gx-5">
                        <div class="col-lg-3">
                            <div class="d-flex align-items-center mt-lg-5 mb-4">
                                <img class="img-fluid rounded-circle" src="https://dummyimage.com/50x50/ced4da/6c757d.jpg" alt="..." />
                                <div class="ms-3">
                                    <div class="fw-bold">Valerie Luna</div>
                                    <div class="text-muted">News, Business</div>
                                </div>
                            </div>
                        </div>
                        <div class="col-lg-9">
                            <!-- Post content-->
                            <article>
                                <!-- Post header-->
                                <header class="mb-4">
                                    <!-- Post title-->
                                    <h1 class="fw-bolder mb-1">Welcome to Blog Post!</h1>
                                    <!-- Post meta content-->
                                    <div class="text-muted fst-italic mb-2">January 1, 2023</div>
                                    <!-- Post categories-->
                                    <a class="badge bg-secondary text-decoration-none link-light" href="#!">Web Design</a>
                                    <a class="badge bg-secondary text-decoration-none link-light" href="#!">Freebies</a>
                                </header>
                                <!-- Preview image figure-->
                                <figure class="mb-4"><img class="img-fluid rounded" src="https://dummyimage.com/900x400/ced4da/6c757d.jpg" alt="..." /></figure>
                                <!-- Post content-->
                                <section class="mb-5">
                                    {blog_content}
                                </section>
                            </article>
                        </div>
                    </div>
                </div>
            </section>
        </main>
        <!-- Footer-->
        <footer class="bg-dark py-4 mt-auto">
            <div class="container px-5">
                <div class="row align-items-center justify-content-between flex-column flex-sm-row">
                    <div class="col-auto"><div class="small m-0 text-white">Copyright &copy; Your Website 2023</div></div>
                    <div class="col-auto">
                        <a class="link-light small" href="#!">Privacy</a>
                        <span class="text-white mx-1">&middot;</span>
                        <a class="link-light small" href="#!">Terms</a>
                        <span class="text-white mx-1">&middot;</span>
                        <a class="link-light small" href="#!">Contact</a>
                    </div>
                </div>
            </div>
        </footer>
        <!-- Bootstrap core JS-->
        <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
        <!-- Core theme JS-->
        <script src="js/scripts.js"></script>
    </body>
    </html>
    """.format(blog_content=blog_content)

    # Save the HTML content to a file
    save_to_html(html_content, html_file_path)
    print("\nHTML file created with blog content.")

    # Save the blog content to a JSON file
    save_to_json(blog_content, json_file_path)
    print("\nBlog content saved to JSON file.")

if __name__ == "__main__":
    main()
# Out:
# HTML file created with blog content.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 185
#     182     print("\nBlog content saved to JSON file.")
#     184 if __name__ == "__main__":
# --> 185     main()
#
# Cell In[29], line 181, in main()
#     178 print("\nHTML file created with blog content.")
#     180 # Save the blog content to a JSON file
# --> 181 save_to_json(blog_content, json_file_path)
#     182 print("\nBlog content saved to JSON file.")
#
# TypeError: save_to_json() missing 1 required positional argument: 'file_path'

# %%
import json
import requests
import os

# Generate blog content using OpenAI's API
def generate_blog(api_key, prompt):
    url = "https://api.openai.com/v1/chat/completions"
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json",
    }
    data = {
        "model": "gpt-3.5-turbo",
        "messages": [
            {"role": "system", "content": "Create a blog post."},
            {"role": "user", "content": prompt}
        ]
    }

    response = requests.post(url, headers=headers, json=data)
    response_data = response.json()

    if 'choices' in response_data and response_data['choices']:
        blog_content = response_data['choices'][0]['message']['content'].strip()
        return blog_content
    else:
        return "Error: No content generated by the API."

# Save the blog content as an HTML file
def save_to_html(html_content, file_path):
    # Ensure the directory exists before saving
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    # Write the HTML content to the specified file path
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(html_content)

# Save the blog content as a JSON file
def save_to_json(html_content, blog_number, file_path):
    new_entry = {
        "html_content": html_content,
        "blog_number": blog_number
    }
    
    # Check if the JSON file exists and load its content; if not, create an empty list
    if os.path.exists(file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            try:
                existing_data = json.load(file)
            except json.JSONDecodeError:  # Handle empty or invalid JSON file
                existing_data = []
    else:
        existing_data = []

    # Append new blog content to existing data
    existing_data.append(new_entry)

    # Ensure the directory exists before saving
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    # Write the JSON data to the specified file path
    with open(file_path, 'w', encoding='utf-8') as file:
        json.dump(existing_data, file, ensure_ascii=False)

# Main execution function
def main():
    api_key = "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"  # Use your actual API key
    prompt = input("What is the topic of the blog?")  # You can change the prompt or use input() to get user input

    # Generate the blog content
    blog_content = generate_blog(api_key, prompt)

    # Define the file paths
    json_file_path = "C:\\Projects\\Store\\dist\\blog.json"  # Path where the JSON file will be saved
    html_folder_path = "C:\\Projects\\Store\\dist\\newblog"  # Folder where the HTML files will be saved
    
    # Create the folder for HTML files if it doesn't exist
    os.makedirs(html_folder_path, exist_ok=True)

    existing_blogs = [f for f in os.listdir(html_folder_path) if f.startswith('blog_') and f.endswith('.html')]
    highest_number = 0
    for blog_file in existing_blogs:
        # This strips off 'blog_' and '.html' and converts the remaining number to an integer
        number = int(blog_file.replace('blog_', '').replace('.html', ''))
        highest_number = max(highest_number, number)
    blog_number = highest_number + 1
    # Determine the new blog number
    html_file_name = f"blog_{blog_number}.html"
    html_file_path = os.path.join(html_folder_path, html_file_name)
    
    html_content = f"""
    <!DOCTYPE html>
    <html lang="he" dir="rtl">
    <head>
        <meta charset="utf-8" />
        <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" />
        <meta name="description" content="" />
        <meta name="author" content="" />
        <title>Modern Business - Start Bootstrap Template</title>
        <!-- Favicon-->
        <link rel="icon" type="image/x-icon" href="assets/favicon.ico" />
        <!-- Bootstrap icons-->
        <link href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.5.0/font/bootstrap-icons.css" rel="stylesheet" />
        <!-- Core theme CSS (includes Bootstrap)-->
        <link href="css/styles.css" rel="stylesheet" />
    </head>
    <body class="d-flex flex-column">
        <main class="flex-shrink-0">
            <!-- Navigation-->
             <nav class="navbar navbar-expand-lg navbar-dark bg-dark">
                <div class="container px-5">
                    <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation"><span class="navbar-toggler-icon"></span></button>
                    <div class="collapse navbar-collapse" id="navbarSupportedContent">
                        <ul class="navbar-nav ms-auto mb-2 mb-lg-0">
                            <li class="nav-item"><a class="nav-link" href="/dist/index.html">דף הבית</a></li>
                            <li class="nav-item"><a class="nav-link" href="/dist/about.html">עלינו</a></li>
                            <li class="nav-item"><a class="nav-link" href="/dist/contact.html">צור קשר</a></li>
                            <li class="nav-item"><a class="nav-link" href="/dist/pricing.html">מחירים</a></li>
                            <li class="nav-item"><a class="nav-link" href="/dist/faq.html">מידע נוסף</a></li>
                            <li class="nav-item dropdown">
                                <a class="nav-link dropdown-toggle" id="navbarDropdownBlog" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">בלוג</a>
                                <ul class="dropdown-menu dropdown-menu-end" aria-labelledby="navbarDropdownBlog">
                                    <li><a class="dropdown-item" href="/dist/blog-home.html">בלוג - דף הבית</a></li>
                                    <li><a class="dropdown-item" href="/dist/blog-post.html">פוסטים</a></li>
                                </ul>
                            </li>
                            <li class="nav-item dropdown">
                                <a class="nav-link dropdown-toggle" id="navbarDropdownPortfolio" href="#" role="button" data-bs-toggle="dropdown" aria-expanded="false">תיק עבודות</a>
                                <ul class="dropdown-menu dropdown-menu-end" aria-labelledby="navbarDropdownPortfolio">
                                    <li><a class="dropdown-item" href="/dist/portfolio-overview.html">צפה בתוצרים שלנו</a></li>
                                    <li><a class="dropdown-item" href="/dist/portfolio-item.html">להקת אהלן </a></li>
                                </ul>
                            </li>
                        </ul>
                    </div>
                </div>
                <a class="navbar-brand" href="/dist/index.html"><img src="/dist/assets/LOGO33 (1).png" Id="Logo" alt=""></a>
            </nav>
            <!-- Page Content-->
            <section class="py-5">
                <div class="container px-5 my-5">
                    <div class="row gx-5">
                        <div class="col-lg-3">
                            <div class="d-flex align-items-center mt-lg-5 mb-4">
                                <img class="img-fluid rounded-circle" src="https://dummyimage.com/50x50/ced4da/6c757d.jpg" alt="..." />
                                <div class="ms-3">
                                    <div class="fw-bold">Valerie Luna</div>
                                    <div class="text-muted">News, Business</div>
                                </div>
                            </div>
                        </div>
                        <div class="col-lg-9">
                            <!-- Post content-->
                            <article>
                                <!-- Post header-->
                                <header class="mb-4">
                                    <!-- Post title-->
                                    <h1 class="fw-bolder mb-1">Welcome to Blog Post!</h1>
                                    <!-- Post meta content-->
                                    <div class="text-muted fst-italic mb-2">January 1, 2023</div>
                                    <!-- Post categories-->
                                    <a class="badge bg-secondary text-decoration-none link-light" href="#!">Web Design</a>
                                    <a class="badge bg-secondary text-decoration-none link-light" href="#!">Freebies</a>
                                </header>
                                <!-- Preview image figure-->
                                <figure class="mb-4"><img class="img-fluid rounded" src="https://dummyimage.com/900x400/ced4da/6c757d.jpg" alt="..." /></figure>
                                <!-- Post content-->
                                <section class="mb-5">
                                    {blog_content}
                                </section>
                            </article>
                        </div>
                    </div>
                </div>
            </section>
            <section class="mb-5">
    <h3>הגיבו </h3>
    <form id="commentForm">
        <div class="mb-3">
            <label for="commentAuthor" class="form-label">שם:</label>
            <input type="text" class="form-control" id="commentAuthor" required>
        </div>
        <div class="mb-3">
            <label for="commentContent" class="form-label">תוכן התגובה:</label>
            <textarea class="form-control" id="commentContent" rows="3" required></textarea>
        </div>
        <button type="submit" class="btn btn-primary">שלח תגובה</button>
    </form>
    <div id="commentsList" class="mt-4">
        <!-- Comments will be dynamically added here -->
    </div>
</section>
        </main>
        <!-- Footer-->
        <footer class="bg-dark py-4 mt-auto">
            <div class="container px-5">
                <div class="row align-items-center justify-content-between flex-column flex-sm-row">
                    <div class="col-auto"><div class="small m-0 text-white">Copyright &copy; Your Website 2023</div></div>
                    <div class="col-auto">
                        <a class="link-light small" href="#!">Privacy</a>
                        <span class="text-white mx-1">&middot;</span>
                        <a class="link-light small" href="#!">Terms</a>
                        <span class="text-white mx-1">&middot;</span>
                        <a class="link-light small" href="#!">Contact</a>
                    </div>
                </div>
            </div>
        </footer>
        <!-- Bootstrap core JS-->
        <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.3/dist/js/bootstrap.bundle.min.js"></script>
        <!-- Core theme JS-->
        <script src="js/scripts.js"></script>
        <link href="/dist/css/styles.css" rel="stylesheet" />
    </body>
    </html>
    """
       # Save the content to an HTML file
    save_to_html(html_content, html_file_path)
    print(f"HTML file '{html_file_name}' created with blog content.")

    # Save the content to a JSON file
    save_to_json(blog_content, blog_number, json_file_path)
    print(f"Blog content added to JSON file at '{json_file_path}'.")

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# HTML file 'blog_13.html' created with blog content.
# Blog content added to JSON file at 'C:\Projects\Store\dist\blog.json'.
